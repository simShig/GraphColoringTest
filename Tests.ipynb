# %%
from main import plotPoints,points

plotPoints()
# Out:
# [56.83846470315456, 99.69037780638993, 33.965762274163104, 0.5500625117954683, 11.157137631332137]
# Point(serial_num=1, value=56.83846470315456, col_num=5)
# Point(serial_num=2, value=99.69037780638993, col_num=37)
# Point(serial_num=3, value=33.965762274163104, col_num=34)
# Point(serial_num=4, value=0.5500625117954683, col_num=30)
# Point(serial_num=5, value=11.157137631332137, col_num=26)
# Point(serial_num=6, value=45.73785422615565, col_num=11)
# Point(serial_num=7, value=54.30513530125411, col_num=39)
# Point(serial_num=8, value=39.62351333904456, col_num=32)
# Point(serial_num=9, value=83.49500558311104, col_num=30)
# Point(serial_num=10, value=84.9531268584662, col_num=16)
# Point(serial_num=11, value=82.59025820080844, col_num=6)
# Point(serial_num=12, value=20.99544078824459, col_num=47)
# Point(serial_num=13, value=71.92934843051361, col_num=48)
# Point(serial_num=14, value=53.83595496679126, col_num=10)
# Point(serial_num=15, value=1.9997762169373434, col_num=15)
# ...

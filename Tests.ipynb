# %%
from main import runValues, plotPoints, points

runValues(100)
plotPoints()
# Out:
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# max col is:0
# ...

# %%
from main import plotPoints,points

plotPoints()
# Out:
# [60.08786449326755, 26.140293167662964, 19.805873465725043, 81.57536279561322, 42.03840351519514]
# Point(serial_num=1, value=60.08786449326755, col_num=0)
# Point(serial_num=2, value=26.140293167662964, col_num=0)
# Point(serial_num=3, value=19.805873465725043, col_num=0)
# Point(serial_num=4, value=81.57536279561322, col_num=0)
# Point(serial_num=5, value=42.03840351519514, col_num=0)
# Point(serial_num=6, value=18.836235646934508, col_num=0)
# Point(serial_num=7, value=54.59439882154312, col_num=0)
# Point(serial_num=8, value=88.66342237606243, col_num=0)
# Point(serial_num=9, value=8.025449025525976, col_num=0)
# Point(serial_num=10, value=65.87418061502783, col_num=0)
# Point(serial_num=11, value=92.60292109473987, col_num=0)
# Point(serial_num=12, value=99.37284040420685, col_num=0)
# Point(serial_num=13, value=67.93246697057943, col_num=0)
# Point(serial_num=14, value=32.13959506881439, col_num=0)
# Point(serial_num=15, value=16.732248429175822, col_num=0)
# ...

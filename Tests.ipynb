# %%
from main import runValues, plotPoints, points

runValues(10)
# plotPoints()
# Out:
# current max col is:0
# finished running rectangleColoringAlg...
#
# 	point list:
# 	-----------
# Point(serial_num=1, value=(18.51722322575322,18.51722322575322), col_num=0)
# Point(serial_num=2, value=(94.98898533073618,94.98898533073618), col_num=1)
# Point(serial_num=3, value=(45.97331482979657,45.97331482979657), col_num=2)
# Point(serial_num=4, value=(84.61408087396045,84.61408087396045), col_num=3)
# Point(serial_num=5, value=(94.0330664551853,94.0330664551853), col_num=4)
# Point(serial_num=6, value=(2.6834574312155413,2.6834574312155413), col_num=5)
# Point(serial_num=7, value=(37.01367965564493,37.01367965564493), col_num=6)
# Point(serial_num=8, value=(68.95712297960958,68.95712297960958), col_num=7)
# Point(serial_num=9, value=(38.50873605326275,38.50873605326275), col_num=8)
# Point(serial_num=10, value=(91.52557244374655,91.52557244374655), col_num=9)
#
# 	correctness:
# 	-----------
# all segments has unique color in them, max color is 9

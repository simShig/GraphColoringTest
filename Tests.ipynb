# %%
from main import runValues, plotPoints, points

runValues(10)
# plotPoints()
# Out:
# current max col is:0
# finished running rectangleColoringAlg...
#
# 	point list:
# 	-----------
# Point(serial_num=1, value=(10.210736312086288,10.210736312086288), col_num=0)
# Point(serial_num=2, value=(86.35895916442921,86.35895916442921), col_num=1)
# Point(serial_num=3, value=(2.6277773019115824,2.6277773019115824), col_num=2)
# Point(serial_num=4, value=(44.54275921107561,44.54275921107561), col_num=3)
# Point(serial_num=5, value=(7.030498736285862,7.030498736285862), col_num=4)
# Point(serial_num=6, value=(80.25760318415843,80.25760318415843), col_num=5)
# Point(serial_num=7, value=(49.72338976848354,49.72338976848354), col_num=6)
# Point(serial_num=8, value=(60.96107332726677,60.96107332726677), col_num=7)
# Point(serial_num=9, value=(48.07606793121758,48.07606793121758), col_num=8)
# Point(serial_num=10, value=(52.20050559781262,52.20050559781262), col_num=9)
#
# 	correctness:
# 	-----------
# all segments has unique color in them, max color is 9

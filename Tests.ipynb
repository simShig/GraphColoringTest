# %%
from main import plotPoints,points

plotPoints()
# Out:
# [93.16092266206479, 67.68132697359778, 60.470866083720665, 40.5675242514241, 28.205990166580698]
# Point(serial_num=1, value=93.16092266206479, col_num=24)
# Point(serial_num=2, value=67.68132697359778, col_num=16)
# Point(serial_num=3, value=60.470866083720665, col_num=8)
# Point(serial_num=4, value=40.5675242514241, col_num=41)
# Point(serial_num=5, value=28.205990166580698, col_num=0)
# Point(serial_num=6, value=22.58043841929396, col_num=14)
# Point(serial_num=7, value=86.49795781122708, col_num=11)
# Point(serial_num=8, value=4.888071413024453, col_num=48)
# Point(serial_num=9, value=79.23855100406305, col_num=34)
# Point(serial_num=10, value=80.83456177657105, col_num=28)
# Point(serial_num=11, value=16.065431676682586, col_num=21)
# Point(serial_num=12, value=57.670004413483376, col_num=38)
# Point(serial_num=13, value=49.523189541176336, col_num=14)
# Point(serial_num=14, value=30.8591424402202, col_num=25)
# Point(serial_num=15, value=35.003054348565385, col_num=31)
# ...
